# %% [markdown]
# # Opening Image Files in a Notebook

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### WARNING! Make sure to provide the correct path like we do in our notebooks! ALWAYS confirm that your file path is correct before posting a question on this.

# %%
# WONT GIVE ERROR! GIVES NONE INSTEAD!!!
img = cv2.imread("some/wrong/path.jpg")

# %%
# UH OH!!
print(img)
# Out:
# None

# %%
img = cv2.imread('puppy.jpeg')

# %%
img
# Out:
# array([[[ 82,  99,  96],
#         [ 83, 100,  97],
#         [ 84, 101,  98],
#         ...,
#         [ 44,  97,  94],
#         [ 45,  98,  95],
#         [ 45,  98,  95]],
#
#        [[ 87, 102,  98],
#         [ 87, 102,  98],
#         [ 86, 101,  97],
#         ...,
#         [ 44,  97,  94],
#         [ 44,  97,  94],
#         [ 44,  97,  94]],
#
#        [[ 90, 105, 101],
#         [ 89, 104, 100],
#         [ 87, 102,  98],
#         ...,
#         [ 43,  96,  93],
#         [ 43,  96,  93],
#         [ 43,  96,  93]],
#
#        ...,
#
#        [[154, 125,  98],
#         [152, 123,  96],
#         [151, 122,  95],
#         ...,
#         [131, 107,  87],
#         [130, 106,  86],
#         [129, 105,  85]],
#
#        [[152, 123,  96],
#         [150, 121,  94],
#         [149, 120,  93],
#         ...,
#         [129, 105,  85],
#         [128, 104,  84],
#         [127, 103,  83]],
#
#        [[150, 121,  94],
#         [148, 119,  92],
#         [147, 118,  91],
#         ...,
#         [127, 103,  83],
#         [125, 101,  81],
#         [124, 100,  80]]], dtype=uint8)

# %% [markdown]
# ------------

# %%
img_bgr = cv2.imread('puppy.jpeg')
plt.imshow(img_bgr)

# %% [markdown]
# The image has been correctly loaded by openCV as a numpy array, but the color of each pixel has been sorted as BGR.
# Matplotlib's plot expects an RGB image so, for a correct display of the image, it is necessary to swap those channels.
# This operation can be done either by using openCV conversion functions cv2.cvtColor() or by working directly with the numpy array.

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray = cv2.imread('puppy.jpeg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv2.imread('puppy.jpeg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %% [markdown]
# ## Resize Images

# %%
img_rgb.shape
# width, height, color channels
# Out:
# (400, 400, 3)

# %%
img =cv2.resize(img_rgb,(1300,275))

# %%
plt.imshow(img)

# %% [markdown]
# ### By ratio

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img =cv2.resize(img_rgb,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
# %matplotlib qt
plt.imshow(new_img)

# %% [markdown]
# ### Flipping Images

# %%
# %matplotlib inline

# %%
# Along central x axis
new_img = cv2.flip(new_img,0)
plt.imshow(new_img)

# %%
# Along central y axis
new_img = cv2.flip(new_img,1)
plt.imshow(new_img)

# %%
# Along both axis
new_img = cv2.flip(new_img,-1)
plt.imshow(new_img)

# %% [markdown]
# --------

# %% [markdown]
# # Saving Image Files

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('my_new_picture.jpg',new_img)
# Out:
# True

# %% [markdown]
# Keep in mind, the above stored the BGR version of the image.

# %% [markdown]
# ## Larger Displays in the Notebook

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(new_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2107599093c9> in <module>
# ----> 1 fig = plt.figure(figsize=(10,8))
#       2 ax = fig.add_subplot(111)
#       3 ax.imshow(new_img)
#
# NameError: name 'plt' is not defined

# %%
pwd
# Out:
# '/Users/tejakummarikuntla/Movies/cvnd/jose- Python for Computer Vision with OpenCV and Deep Learning/00 Computer-Vision-with-Python/01-Image-Basics-with-OpenCV'
