# %% [markdown]
# # Canny Edge Detection in Action
#
# Now that you have a conceptual grasp on how the Canny algorithm works, it's time to use it to find the edges of the lane lines in an image of the road. So let's give that a try.
#
# ### Steps to Apply Canny Algorithm
# - Read the image
# - Convert the image for RGB to Gray
# - Apply Gaussian Smoothing/Bluring to smooth the image
# - Define lower and Higher Thresholds for Canny function
# - Apply Canny Function to the Blured Image with Lower and Higer Thresholds
#
# so,First we need to import and read in an image:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline

# %% [markdown]
# ## Read and Display

# %%
image = mpimg.imread('images/exit-ramp.jpg')
plt.imshow(image)

# %% [markdown]
# ### Here we have an image of the road, and it's fairly obvious by eye where the lane lines are, but what about using computer vision?
#
# #### Let's go ahead and convert to grayscale.

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) #grayscale conversion
plt.imshow(gray, cmap='gray')

# %% [markdown]
# ### Defining the Kernal and Thresholds

# %%
# Define a kernel size for Gaussian smoothing / blurring
# Note: this step is optional as cv2.Canny() applies a 5x5 Gaussian internally
kernel_size = 3
blur_gray = cv2.GaussianBlur(gray,(kernel_size, kernel_size), 0)

# %%
# Define parameters for Canny and run it
# NOTE: if you try running this code you might want to change these!
low_threshold = 1
high_threshold = 10
edges = cv2.Canny(blur_gray, low_threshold, high_threshold)

# %% [markdown]
# ### Display the final Image

# %%
# Display the image
plt.imshow(edges, cmap='Greys_r')
